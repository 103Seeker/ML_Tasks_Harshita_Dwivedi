# %%
# Scenario: Sports Event Analysis

# Context:

# You are part of a sports analytics team working for a global media company. Your manager has asked you to analyze match reports and press releases to identify key entities such as teams, players, locations, dates, and numbers. This information will help the company build automated summaries and highlight reels for fans.

# Task:

# You receive the following match report excerpt:

# "Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London. Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024"

# Your job is to run Named Entity Recognition (NER) using spacy to automatically extract structured insights.

# 14:44

# Type a message
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London. Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024."

doc = nlp(text)

for ent in doc.ents:
    print(ent.text, "-", ent.label_)
# Out:
# Manchester United - PERSON
# Wembley Stadium - GPE
# London - GPE
# Cristiano Ronaldo - PERSON
# Marcus Rashford - PERSON
# July 2024 - DATE

# %%
# 📘 Scenario: Sports Event Analysis
# Context:
# You are part of a sports analytics team working for a global media company. Your manager has asked you to analyze match reports and press releases to identify key entities such as teams, players, locations, dates, and numbers. This information will help the company build automated summaries and highlight reels for fans.
# Task:
# You receive the following match report excerpt:
# "Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London. Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024."

# Your job is to run Named Entity Recognition (NER) using spaCy to automatically extract structured insights.
import spacy

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# Match report text
text = "Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London. Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024."

# Process the text
doc = nlp(text)

print("Named Entities Found:\n")

# Extract entities
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_}")
# Out:
# Named Entities Found:
#
# Manchester United -> PERSON
# Wembley Stadium -> GPE
# London -> GPE
# Cristiano Ronaldo -> PERSON
# Marcus Rashford -> PERSON
# July 2024 -> DATE

# %%
# 📘 Scenario: Smart Manufacturing Insights
# Context:
# You are part of a data science team in a smart manufacturing company. Your manager wants you to explore how different 
# technical concepts (like maintenance, telemetry, quality control, supply chain) are related in company documents. 
# By training a small Word2Vec model, you can uncover semantic similarities between words and measure how closely they are
#  connected. This helps in building recommendation systems, knowledge graphs, or even automated reporting tools.
# Task:
# Given a short corpus describing manufacturing operations, train a Word2Vec model and analyze word similarities.


from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk

# Download tokenizer resources
nltk.download('punkt')
nltk.download('punkt_tab')

# Manufacturing corpus
corpus = [
    "The factory uses predictive maintenance to reduce machine downtime",
    "Telemetry sensors collect real time data from manufacturing equipment",
    "Quality control ensures products meet industry standards",
    "Supply chain management helps track raw materials and deliveries",
    "Machine learning improves predictive maintenance in factories"
]

# Tokenize sentences
tokenized_corpus = [word_tokenize(sentence.lower()) for sentence in corpus]

# Train Word2Vec model
model = Word2Vec(sentences=tokenized_corpus, vector_size=50, window=3, min_count=1, workers=2)

# Find similar words
print("Words similar to 'maintenance':")
print(model.wv.most_similar("maintenance"))

print("\nWords similar to 'machine':")
print(model.wv.most_similar("machine"))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# Words similar to 'maintenance':
# [('sensors', 0.3756771683692932), ('standards', 0.22985278069972992), ('real', 0.22091351449489594), ('from', 0.21887437999248505), ('reduce', 0.19467346370220184), ('products', 0.16069543361663818), ('meet', 0.1488102674484253), ('in', 0.1249273419380188), ('downtime', 0.11050435155630112), ('telemetry', 0.09342671930789948)]
#
# Words similar to 'machine':
# [('meet', 0.27076104283332825), ('downtime', 0.24065978825092316), ('chain', 0.2107398509979248), ('equipment', 0.18607693910598755), ('track', 0.16717004776000977), ('quality', 0.16080081462860107), ('management', 0.1501249074935913), ('collect', 0.14492756128311157), ('deliveries', 0.1320544332265854), ('predictive', 0.12676812708377838)]

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk

# Download tokenizer resources
nltk.download('punkt')
nltk.download('punkt_tab')

# Healthcare corpus
corpus = [
    "Doctors diagnose patients based on symptoms and medical history",
    "Treatment includes medication and regular monitoring",
    "Patients receive medication to manage chronic diseases",
    "Symptoms such as fever and cough help doctors identify infections",
    "Early diagnosis improves treatment outcomes for patients"
]

# Tokenize sentences
tokenized_corpus = [word_tokenize(sentence.lower()) for sentence in corpus]

model = Word2Vec(sentences=tokenized_corpus, vector_size=50, window=3, min_count=1, workers=2)

# Analyze similarities
print("Words similar to 'diagnosis':")
print(model.wv.most_similar("diagnosis"))

print("\nWords similar to 'treatment':")
print(model.wv.most_similar("treatment"))

print("\nWords similar to 'patients':")
print(model.wv.most_similar("patients"))
# Out:
# Words similar to 'diagnosis':
# [('on', 0.26368826627731323), ('doctors', 0.22464197874069214), ('includes', 0.2004113346338272), ('medical', 0.19234111905097961), ('regular', 0.12750066816806793), ('help', 0.12649784982204437), ('cough', 0.11862187832593918), ('diagnose', 0.1015445813536644), ('and', 0.09995406121015549), ('manage', 0.09686045348644257)]
#
# Words similar to 'treatment':
# [('regular', 0.2282945215702057), ('based', 0.2035502791404724), ('identify', 0.19014227390289307), ('medical', 0.13087129592895508), ('includes', 0.05804729834198952), ('receive', 0.04905153065919876), ('monitoring', 0.04866178333759308), ('outcomes', 0.044939909130334854), ('improves', -0.010298204608261585), ('and', -0.014518423937261105)]
#
# Words similar to 'patients':
# [('diagnose', 0.37581440806388855), ('as', 0.2301507145166397), ('on', 0.22097940742969513), ('includes', 0.21907953917980194), ('chronic', 0.16084854304790497), ('diseases', 0.14884990453720093), ('symptoms', 0.1251128613948822), ('identify', 0.08064670115709305), ('for', 0.07399441301822662), ('to', 0.05544072389602661)]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
