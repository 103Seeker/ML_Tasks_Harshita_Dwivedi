# %%
import pandas as pd
df = pd.read_csv("sample_data1.csv")
df.head()
df.shape
df.info()
df.describe()
df.isnull().sum()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         15 non-null     int64
#  1   Department          15 non-null     str
#  2   Region              15 non-null     str
#  3   Salary              15 non-null     int64
#  4   Experience_Years    15 non-null     int64
#  5   Performance_Rating  14 non-null     float64
#  6   Monthly_Sales       14 non-null     float64
# dtypes: float64(2), int64(3), str(2)
# memory usage: 972.0 bytes
#    Employee_ID Department Region  Salary  Experience_Years  \
# 0         1001      Sales  North   45000                 2
# 1         1002  Marketing  South   52000                 3
# 2         1003      Sales   East   47000                 4
# 3         1004         HR   West   40000                 1
# 4         1005         IT  North   60000                 5
#
# ...

# %%
import pandas as pd
df = pd.read_csv("employee_attrition.csv")
df.head()
df.shape
df.info()
df.describe()
df.isnull().sum()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       15 non-null     str
#  1   Age               15 non-null     int64
#  2   Department        15 non-null     str
#  3   Job_Role          15 non-null     str
#  4   Monthly_Income    15 non-null     int64
#  5   Years_at_Company  15 non-null     int64
#  6   Overtime          15 non-null     str
#  7   Job_Satisfaction  14 non-null     float64
#  8   Attrition         15 non-null     str
# dtypes: float64(1), int64(3), str(5)
# memory usage: 1.2 KB
#   Employee_ID  Age Department           Job_Role  Monthly_Income  \
# 0        E001   29      Sales    Sales Executive           45000
# 1        E002   35         HR         HR Manager           52000
# 2        E003   28         IT  Software Engineer           60000
# ...

# %%
import pandas as pd
df = pd.read_csv("telecom_churn.csv")
df.head()
df.shape
df.info()
df.describe()
df.isnull().sum()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       15 non-null     str
#  1   Gender            15 non-null     str
#  2   Age               15 non-null     int64
#  3   Tenure_Months     15 non-null     int64
#  4   Monthly_Charges   15 non-null     int64
#  5   Contract_Type     15 non-null     str
#  6   Internet_Service  15 non-null     str
#  7   Payment_Method    15 non-null     str
#  8   Churn             14 non-null     str
# dtypes: int64(3), str(6)
# memory usage: 1.2 KB
#   Customer_ID  Gender  Age  Tenure_Months  Monthly_Charges   Contract_Type  \
# 0        C001    Male   25              6              500  Month-to-Month
# 1        C002  Female   34             24              750        One Year
# 2        C003    Male   45             36              820        Two Year
# ...

# %%
# Broadcasting
import numpy as np
prices = np.array([1,2,3,4])
prices * 1.10
# Indexing Slicing
prices[1:3]
# Out:
# array([2, 3])

# %%
# Retail Sales analysis
import numpy as np
sales_day1 = np.array([120, 89, 90])
sales_day2 = np.array([150, 90, 75])

# Total sales per product across 2 days
total_sales = sales_day1 + sales_day2
print("Total sales per product:", total_sales)

# Total sales each day
day1_sale = np.sum(sales_day1)
day2_sale = np.sum(sales_day2)

# Percentage growth from day1 to day2
percent_growth = ((day2_sale - day1_sale) / day1_sale) * 100
print("Overall percentage growth:", percent_growth)

# Product with highest growth
highest_growth_product = np.argmax(product_growth)
print("Product with highest growth index:", highest_growth_product)
# Out:
# Total sales per product: [270 179 165]
# Overall percentage growth: 5.351170568561873
# Growth per product: [ 30   1 -15]
# Product with highest growth index: 0

# %%
# Weather Data(Broadcasting)
import numpy as np
temps = np.array([[25,23,45],
                 [34,67,86],
                 [32,12,25],
                 [20,21,23]])
# Convert all temps in fahrenheit using broadcasting
Fahrenheit = ((temps * 9/5) + 32)
print("Fahrenheit temps are:\n", Fahrenheit)
# Add a correction factor [1, -1, 0] to adjust readings for sensor bias.
correction = np.array([1, -1, 0])
adjusted_temps = temps + correction
print("\nAdjusted Celsius temps:\n", adjusted_temps)
# If you also want adjusted Fahrenheit:
adjusted_fahrenheit = (adjusted_temps * 9/5) + 32
print("\nAdjusted Fahrenheit temps:\n", adjusted_fahrenheit)
# Out:
# Fahrenheit temps are:
#  [[ 77.   73.4 113. ]
#  [ 93.2 152.6 186.8]
#  [ 89.6  53.6  77. ]
#  [ 68.   69.8  73.4]]
#
# Adjusted Celsius temps:
#  [[26 22 45]
#  [35 66 86]
#  [33 11 25]
#  [21 20 23]]
#
# Adjusted Fahrenheit temps:
#  [[ 78.8  71.6 113. ]
#  [ 95.  150.8 186.8]
#  [ 91.4  51.8  77. ]
#  [ 69.8  68.   73.4]]

# %%
# Health Care Dataset
import numpy as np
bp = np.array([[120,80],
                 [134,85],
                 [140,90],
                 [125,75]])
# Extract systolic values
systolic_values = bp[:, 0]
print("The systolic values are:\n", systolic_values)
# Patients with systolic > 130 using boolean indexing
high_values = bp[bp[:, 0] > 130]
print("Ptients with systolic > 130:\n", high_values)
# Replace all < 80 with 80
bp[bp<80] = 80
print("Replace:\n", bp)
# Out:
# The systolic values are:
#  [120 134 140 125]
# Ptients with systolic > 130:
#  [[134  85]
#  [140  90]]
# Replace:
#  [[120  80]
#  [134  85]
#  [140  90]
#  [125  80]]

# %%
# Agriculture Yield
import numpy as np
yields = np.array([[2.5, 3.0, 1.0],
                 [2.8, 3.2, 2.0],
                 [3.1, 2.9, 2.2],
                 [2.6, 3.1, 1.9]])
# Inc yeilds of 2nd region by [0.2, 0.3, 0.1]
sec_reg = yields[1] + [0.2, 0.3, 0.1]
print("Updated second region:\n",sec_reg)
# Multiply last col by 1.1 to stimulate fertilizer impact
crop_C = yields[:, 2] * 1.1
print("Updated last col:\n",crop_C)
# Highest avg yields accross all region
highest_avg = np.max(np.mean(yields, axis=1))
print("Highest average yield:", highest_avg)
# Out:
# Updated second region:
#  [3.  3.5 2.1]
# Updated last col:
#  [1.1  2.2  2.42 2.09]
# Highest average yield: 2.733333333333333

# %%
import numpy as np
yields = np.array([
    [3200, 3500, 3000, 2800],
    [4000, 4200, 3900, 4100],
    [2800, 3000, 3100, 2900]
])

# Increase all yields by 10% to account for improved irrigation.
increase_yields = yields * 1.10
print("After 10% increase Yields:\n", increase_yields)

# Extract only Wheat’s yields (the first crop).
first_crop = increase_yields[0]
print("Extracted Wheat yields:\n", first_crop)

# Find the average yield per crop across all seasons.
avg_yield = np.mean(increase_yields, axis=1)
print("Average per crop:\n", avg_yield)

# Identify yields greater than 3000 kg (to see which crops/seasons performed exceptionally well).
high_yields = increase_yields[increase_yields > 3000]

print("Yields > 3000:\n", high_yields)
# Out:
# After 10% increase Yields:
#  [[3520. 3850. 3300. 3080.]
#  [4400. 4620. 4290. 4510.]
#  [3080. 3300. 3410. 3190.]]
# Extracted Wheat yields:
#  [3520. 3850. 3300. 3080.]
# Average per crop:
#  [3437.5 4455.  3245. ]
# Yields > 3000:
#  [3520. 3850. 3300. 3080. 4400. 4620. 4290. 4510. 3080. 3300. 3410. 3190.]

# %%
# Education Dataset stored score of three subjects
scores = np.array([[25,67,78],
                  [90,58,97],
                  [38,86,67],
                  [90,78,89]])
# Extract score of top 2 students
top_two = scores[0:2]
# Get all math scores(1st column)
math_score = scores[:, 0]
print("Maths score: \n", math_score)
# Students who scored > 90 in science (3rd column)
higher_science = scores[scores[:, 2] > 90]
print("Students who score > 90: \n", higher_science)
# Out:
# Maths score:
#  [25 90 38 90]
# Students who score > 90:
#  [[90 58 97]]

# %%
# Dataframes
import pandas as pd
data = {"Name" : ["A", "B", "C"],
        "Age" : [1, 2, 3]
    }
df = pd.DataFrame(data)
print(df)
df.head()
df.info()
df[df["Region"] == "North"]
df.groupby("Region")["Monthly_Sales"].sum()
# Out:
#   Name  Age
# 0    A    1
# 1    B    2
# 2    C    3

# %%
import pandas as pd
import numpy as np

customers = pd.read_csv("Customers.csv")
sales = pd.read_csv("Sales.csv")   
support = pd.read_csv("Support.csv")

print("\nCustomers Info:")
print(customers.info())
print("\nSales Info:")
print(sales.info())
print("\nSupport Info:")
print(support.info())

customers["Age"].fillna(customers["Age"].median(), inplace=True)

customers.rename(columns={"CustomerID": "Cust_ID"}, inplace=True)
sales.rename(columns={"CustomerID": "Cust_ID"}, inplace=True)
support.rename(columns={"CustomerID": "Cust_ID"}, inplace=True)

sales["DiscountedPrice"] = sales["Price"] * 0.9

# Compute revenue per order
sales["Revenue"] = sales["Quantity"] * sales["Price"]

april_orders = sales[sales["OrderDate"].str.startswith("2023-04")]
print("\nApril Orders:\n", april_orders)

# Slice first 5 rows of sales
print("\nFirst 5 Sales Records:\n", sales.head())

north_customers = customers[customers["Region"] == "North"]

high_value_orders = sales[sales["Revenue"] > 50000]

print("\nNorth Customers:\n", north_customers)
print("\nHigh Value Orders:\n", high_value_orders)


sorted_customers = customers.sort_values(by="SignupDate")

sorted_sales = sales.sort_values(by="Revenue", ascending=False)

print("\nSorted Customers:\n", sorted_customers)
print("\nSorted Sales:\n", sorted_sales)


avg_revenue_product = sales.groupby("Product")["Revenue"].mean()

avg_resolution_issue = support.groupby("IssueType")["ResolutionTime"].mean()

print("\nAverage Revenue per Product:\n", avg_revenue_product)
print("\nAverage Resolution Time per Issue Type:\n", avg_resolution_issue)


merged_data = sales.merge(customers, on="Cust_ID").merge(support, on="Cust_ID")

print("\nMerged Dataset:\n", merged_data.head())


clv = sales.groupby("Cust_ID")["Revenue"].sum().reset_index()
clv.rename(columns={"Revenue": "CustomerLifetimeValue"}, inplace=True)

customers = customers.merge(clv, on="Cust_ID", how="left")

print("\nCustomers with CLV:\n", customers)

merged_data.to_csv("Cleaned_Data.csv", index=False)
print("\nCleaned dataset exported to Cleaned_Data.csv")
# Out:
# Customers Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  8 non-null      str
#  1   Name        8 non-null      str
#  2   Age         7 non-null      float64
#  3   Region      8 non-null      str
#  4   SignupDate  8 non-null      str
# dtypes: float64(1), str(4)
# memory usage: 452.0 bytes
# None
#
# Sales Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderID     8 non-null      str
#  1   CustomerID  8 non-null      str
#  2   Product     8 non-null      str
#  3   Quantity    8 non-null      int64
#  4   Price       8 non-null      int64
#  5   OrderDate   8 non-null      str
# dtypes: int64(2), str(4)
# memory usage: 516.0 bytes
# None
#
# Support Info:
# <class 'pandas.DataFrame'>
# ...

# %%
import matplotlib.pyplot as plt
months = ["Jan", "Feb", "Mar", "Apr"]
sales = [10000, 12000, 13000, 16000]
plt.plot(months,sales)
plt.title("Monthly sales trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
months = ["Jan", "Feb", "Mar", "Apr"]
attendance = [85, 90, 95, 88]
plt.plot(months, attendance)
plt.title("Monthly attendance Track record")
plt.xlabel("Months")
plt.ylabel("Attendance")
plt.show()
# Which month has highest attendance
# Did attendance steadly increase, or were there ups and doens
# What might explain dip in month of april

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
months = ["Jan", "Feb", "Mar", "Apr"]
attendance = [85, 90, 95, 88]

max_attendance = max(attendance)
max_month = months[attendance.index(max_attendance)]

print("Highest Attendance:", max_attendance)
print("Month with Highest Attendance:", max_month)

differences = np.diff(attendance)
print("Monthly Changes:", differences)

x = np.arange(len(attendance))   # numeric index for months
coefficients = np.polyfit(x, attendance, 1)  # degree 1 = straight line
trend_line = np.poly1d(coefficients)

print("Trend Line Equation: y = {:.2f}x + {:.2f}".format(coefficients[0], coefficients[1]))


plt.plot(months, attendance, marker='o', label="Attendance")
plt.plot(months, trend_line(x), linestyle='--', label="Trend Line")

plt.title("Monthly Attendance Track Record")
plt.xlabel("Months")
plt.ylabel("Attendance")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Highest Attendance: 95
# Month with Highest Attendance: Mar
# Monthly Changes: [ 5  5 -7]
# Trend Line Equation: y = 1.40x + 87.40

# %%
regions = ["North", "South", "East", "West"]
revenue = [2000000, 1500000, 3000000, 4500000]
plt.bar(regions, revenue)
plt.title("Revenue by region")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

regions = ["North", "South", "East", "West"]
books = [1000, 1500, 1700, 6000]

highest_activity = max(books)
high_activity_region = regions[books.index(highest_activity)]

print("Highest checkout books:", highest_activity)
print("Region with Highest Checkout:", high_activity_region)

lowest_activity = min(books)
low_activity_region = regions[books.index(lowest_activity)]

print("Lowest checkout books:", lowest_activity)
print("Region with Lowest Checkout:", low_activity_region)

x = np.arange(len(books))   # FIXED (was arrange)
coefficients = np.polyfit(x, books, 1)
trend_line = np.poly1d(coefficients)

print("Trend Line Equation: y = {:.2f}x + {:.2f}".format(coefficients[0], coefficients[1]))

plt.bar(regions, books, label="Books")

plt.plot(regions, trend_line(x), linestyle='--', label="Trend Line")

plt.title("Books Checkout by Region")
plt.xlabel("Regions")
plt.ylabel("Number of Books")
plt.legend()

plt.show()
# Out:
# Highest checkout books: 6000
# Region with Highest Checkout: West
# Lowest checkout books: 1000
# Region with Lowest Checkout: North
# Trend Line Equation: y = 1520.00x + 270.00

# %%
# A professor recorded the exam scores of 1,000 students in a statistics course. The average 
# score was around 75 marks, with most students scoring within a spread of about 10 marks.
# - What does the shape of the distribution suggest about student performance?
# - Are most students clustered around the average, or is there wide variation?
# - How could the professor use this information to adjust teaching methods?

import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)
scores = np.random.normal(loc=75, scale=10, size=1000)

plt.hist(scores, bins=20)
plt.title("Distribution of Exam Scores")
plt.xlabel("Exam Scores")
plt.ylabel("Number of Students")
plt.show()

mean_score = np.mean(scores)
std_dev = np.std(scores)
min_score = np.min(scores)
max_score = np.max(scores)

print("Mean Score:", round(mean_score, 2))
print("Standard Deviation:", round(std_dev, 2))
print("Minimum Score:", round(min_score, 2))
print("Maximum Score:", round(max_score, 2))

# Students within 1 standard deviation (mean ± std)
lower_bound = mean_score - std_dev
upper_bound = mean_score + std_dev

within_one_std = np.sum((scores >= lower_bound) & (scores <= upper_bound))

print("Students within 1 standard deviation:", within_one_std)
print("Percentage within 1 std:", round((within_one_std / len(scores)) * 100, 2), "%")
# Out:
# Mean Score: 75.19
# Standard Deviation: 9.79
# Minimum Score: 42.59
# Maximum Score: 113.53
# Students within 1 standard deviation: 686
# Percentage within 1 std: 68.6 %

# %%
📘 Scenario Question
# A company surveyed the salaries of 1,000 employees. The average salary was around $50,000, with most employees earning
#  within a spread of about $10,000.
# The HR department wants to visualize the distribution of salaries to understand pay structure and
#  identify whether salaries are
#  clustered around the average or spread out widely.
# You are asked to:
# - Plot a histogram showing the salary distribution.
# - Add a title to make the chart clear.
# - Interpret the chart:
# - What does the shape of the distribution suggest about how salaries are spread?
# - Are most employees earning close to the average, or is there a wide variation?
# - How could HR use this information to review compensation policies?

# %%
regions = ["North", "South", "East", "West"]
books = [1000, 1500, 1700, 6000]

colors = ["blue", "green", "orange", "red"]

plt.bar(regions, books, color=colors)

plt.title("Books Checkout by Region")
plt.xlabel("Regions")
plt.ylabel("Number of Books")

plt.show()

# %%
fig, ax = plt.subplot(figsize = (8,5))
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [32000, 55400, 55000, 37000, 25000]
ax.plot(months, plot, color = 'Blue', linewidth = 2.4, marker = 'o', markersize = 8)
ax.set_title('Monthly sales 2024', fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Revenue ($)')
ax.grid(axis='y', alpha = 0.4)
plt.tight_layout()
plt.show()[kl;

# %%
# 📘 Scenario Question
# A company wants to analyze whether advertising spend impacts sales revenue. The marketing team collected data from
#  several campaigns, where ad spend ranged from $2,000 to $18,000 and the corresponding sales revenue was recorded.
# You are asked to:
# - Plot a scatter chart showing the relationship between ad spend and sales.
# - Add a trend line to highlight the overall pattern.
# - Interpret the chart: does higher ad spend generally lead to higher sales?
ad_spend = np.array([1000, 2000, 4000, 6000, 8000, 5000])
sales = np.array([7000, 8000, 1500, 2100, 3300, 8000])

# Scatter 
plt.scatter(ad_spend, sales, color = 'blue', alpha = 0.4)
# Trend_line
z = np.polyfit(ad_spend, sales, 1)
p = np.polyqd(z)
plt.plot(ad_spend, p(ad_spend), 'r--', label = 'Trend')

plt.xlabel('Ad Spend ($)')
plt.ylabel('Sales ($)')
plt.legend()
pl.show()

# %%
Probability

# %%
import numpy as np

heads = 0
total = 1000

for i in range(total):
    result = np.random.randint(0, 2)   
    if result == 1:
        heads += 1

tails = total - heads

print("Heads:", heads)
print("Tails:", tails)
print("P(Heads):", heads/total)
# Out:
# Heads: 493
# Tails: 507
# P(Heads): 0.493

# %%
import numpy as np
import matplotlib.pyplot as plt
heights = np.random.normal(165, 8, 200)

print("Shortest: ", round(heights.min()), 1)
print("Tallest: ", round(heights.max()), 1)
print("Average: ", round(heights.mean()), 1)

plt.hist(heights, bins = 20, color = 'Yellow', edgecolor = 'white')
plt.axvline(heights.mean(), color = 'red', linewidth = 2, label = 'Average')
plt.title('Heights of 200 students')
plt.xlabel('Height (cm)')
plt.ylabel('Number of students')
plt.legend()
plt.show()
# Out:
# Shortest:  142 1
# Tallest:  185 1
# Average:  165 1
